# %%
# !git clone https://github.com/ultralytics/yolov5.git  # clone repo
# %cd yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16517, done.
# remote: Counting objects: 100% (115/115), done.
# remote: Compressing objects: 100% (99/99), done.
# remote: Total 16517 (delta 47), reused 50 (delta 16), pack-reused 16402
# Receiving objects: 100% (16517/16517), 15.12 MiB | 23.82 MiB/s, done.
# Resolving deltas: 100% (11309/11309), done.
# /content/yolov5

# %%
# install dependencies as necessary
# !pip install -qr requirements.txt  # install dependencies (ignore errors)
import torch

from IPython.display import Image, clear_output  # to display images
# from utils.google_utils import gdrive_download  # to download models/datasets

# clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 1.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.3/721.3 kB 8.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 43.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 62.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 48.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 5.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 2.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 3.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 1.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 4.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 9.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 10.4 MB/s eta 0:00:00
# Setup complete. Using torch 2.2.1+cu121 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15102MB, multi_processor_count=40)

# %%
# %cd /content
# %cat data.yaml
# Out:
# /content
# train: ../train/images
# val: ../test/images
#
# nc: 15
# names: ['Bad', 'Good', 'Goodbye', 'Hello', 'Help', 'House', 'Hurt', 'I love you', 'Nice', 'No', 'Please', 'Sorry', 'Thank you', 'Toilet', 'Yes']

# %%
# define number of classes based on YAML
import yaml
with open("data.yaml", 'r') as stream:
    num_classes = str(yaml.safe_load(stream)['nc'])

# %%
num_classes
# Out:
# '15'

# %%
# model configuration
# %cat /content/yolov5/models/yolov5s.yaml
# Out:
# # YOLOv5 🚀 by Ultralytics, AGPL-3.0 license
#
# # Parameters
# nc: 80 # number of classes
# depth_multiple: 0.33 # model depth multiple
# width_multiple: 0.50 # layer channel multiple
# anchors:
#   - [10, 13, 16, 30, 33, 23] # P3/8
#   - [30, 61, 62, 45, 59, 119] # P4/16
#   - [116, 90, 156, 198, 373, 326] # P5/32
#
# # YOLOv5 v6.0 backbone
# backbone:
#   # [from, number, module, args]
#   [
#     [-1, 1, Conv, [64, 6, 2, 2]], # 0-P1/2
#     [-1, 1, Conv, [128, 3, 2]], # 1-P2/4
#     [-1, 3, C3, [128]],
#     [-1, 1, Conv, [256, 3, 2]], # 3-P3/8
#     [-1, 6, C3, [256]],
#     [-1, 1, Conv, [512, 3, 2]], # 5-P4/16
#     [-1, 9, C3, [512]],
#     [-1, 1, Conv, [1024, 3, 2]], # 7-P5/32
#     [-1, 3, C3, [1024]],
#     [-1, 1, SPPF, [1024, 5]], # 9
#   ]
#
# # YOLOv5 v6.0 head
# head: [
#     [-1, 1, Conv, [512, 1, 1]],
#     [-1, 1, nn.Upsample, [None, 2, "nearest"]],
#     [[-1, 6], 1, Concat, [1]], # cat backbone P4
#     [-1, 3, C3, [512, False]], # 13
#
#     [-1, 1, Conv, [256, 1, 1]],
#     [-1, 1, nn.Upsample, [None, 2, "nearest"]],
#     [[-1, 4], 1, Concat, [1]], # cat backbone P3
#     [-1, 3, C3, [256, False]], # 17 (P3/8-small)
#
#     [-1, 1, Conv, [256, 3, 2]],
#     [[-1, 14], 1, Concat, [1]], # cat head P4
#     [-1, 3, C3, [512, False]], # 20 (P4/16-medium)
#
#     [-1, 1, Conv, [512, 3, 2]],
#     [[-1, 10], 1, Concat, [1]], # cat head P5
#     [-1, 3, C3, [1024, False]], # 23 (P5/32-large)
#
#     [[17, 20, 23], 1, Detect, [nc, anchors]], # Detect(P3, P4, P5)
#   ]

# %%
from IPython.core.magic import register_line_cell_magic

@register_line_cell_magic
def writetemplate(line, cell):
    with open(line, 'w') as f:
        f.write(cell.format(**globals()))

# %%
# %%writetemplate /content/yolov5/models/custom_yolov5s.yaml
#
# # parameters
# nc: {num_classes}  # number of classes
# depth_multiple: 0.33  # model depth multiple
# width_multiple: 0.50  # layer channel multiple
#
# # anchors
# anchors:
#   - [10,13, 16,30, 33,23]  # P3/8
#   - [30,61, 62,45, 59,119]  # P4/16
#   - [116,90, 156,198, 373,326]  # P5/32
#
# # YOLOv5 backbone
# backbone:
#   # [from, number, module, args]
#   [[-1, 1, Focus, [64, 3]],  # 0-P1/2
#    [-1, 1, Conv, [128, 3, 2]],  # 1-P2/4
#    [-1, 3, BottleneckCSP, [128]],
#    [-1, 1, Conv, [256, 3, 2]],  # 3-P3/8
#    [-1, 9, BottleneckCSP, [256]],
#    [-1, 1, Conv, [512, 3, 2]],  # 5-P4/16
#    [-1, 9, BottleneckCSP, [512]],
#    [-1, 1, Conv, [1024, 3, 2]],  # 7-P5/32
#    [-1, 1, SPP, [1024, [5, 9, 13]]],
#    [-1, 3, BottleneckCSP, [1024, False]],  # 9
#   ]
#
# # YOLOv5 head
# head:
#   [[-1, 1, Conv, [512, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 6], 1, Concat, [1]],  # cat backbone P4
#    [-1, 3, BottleneckCSP, [512, False]],  # 13
#
#    [-1, 1, Conv, [256, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 4], 1, Concat, [1]],  # cat backbone P3
#    [-1, 3, BottleneckCSP, [256, False]],  # 17 (P3/8-small)
#
#    [-1, 1, Conv, [256, 3, 2]],
#    [[-1, 14], 1, Concat, [1]],  # cat head P4
#    [-1, 3, BottleneckCSP, [512, False]],  # 20 (P4/16-medium)
#
#    [-1, 1, Conv, [512, 3, 2]],
#    [[-1, 10], 1, Concat, [1]],  # cat head P5
#    [-1, 3, BottleneckCSP, [1024, False]],  # 23 (P5/32-large)
#
#    [[17, 20, 23], 1, Detect, [nc, anchors]],  # Detect(P3, P4, P5)
#   ]

# %%
# train yolov5s on custom data for 100 epochs
# time its performance
# %%time
# %cd /content/yolov5/
# !python train.py --img 416 --batch 16 --epochs 300 --data '/content/data.yaml' --cfg ./models/custom_yolov5s.yaml --weights 'yolov5s.pt' --name yolov5s_results  --cache
# Out:
# /content/yolov5
# 2024-03-17 19:59:31.362063: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-17 19:59:31.362112: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-17 19:59:31.363485: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# train: weights=yolov5s.pt, cfg=./models/custom_yolov5s.yaml, data=/content/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=300, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data/hyps, resume_evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=yolov5s_results, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-294-gdb125a20 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Focus                     [3, 32, 3]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     19904  models.common.BottleneckCSP             [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  3    161152  models.common.BottleneckCSP             [128, 128, 3]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    641792  models.common.BottleneckCSP             [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1    656896  models.common.SPP                       [512, 512, [5, 9, 13]]
#   9                -1  1   1248768  models.common.BottleneckCSP             [512, 512, 1, False]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    378624  models.common.BottleneckCSP             [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     95104  models.common.BottleneckCSP             [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    313088  models.common.BottleneckCSP             [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1248768  models.common.BottleneckCSP             [512, 512, 1, False]
#  24      [17, 20, 23]  1     53940  models.yolo.Detect                      [15, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# custom_YOLOv5s summary: 233 layers, 7292852 parameters, 7292852 gradients
#
# Transferred 223/369 items from yolov5s.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 59 weight(decay=0.0), 70 weight(decay=0.0005), 62 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning /content/train/labels.cache... 120 images, 0 backgrounds, 0 corrupt: 100% 120/120 [00:00<?, ?it/s]
# train: Caching images (0.0GB ram): 100% 120/120 [00:01<00:00, 81.63it/s]
# val: Scanning /content/test/labels.cache... 30 images, 0 backgrounds, 0 corrupt: 100% 30/30 [00:00<?, ?it/s]
# val: Caching images (0.0GB ram): 100% 30/30 [00:00<00:00, 56.49it/s]
#
# AutoAnchor: 5.74 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/yolov5s_results/labels.jpg...
# Image sizes 416 train, 416 val
# Using 2 dataloader workers
# Logging results to runs/train/yolov5s_results
# Starting training for 300 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       0/299      1.75G     0.1083    0.02112    0.07129         21        416: 100% 8/8 [00:06<00:00,  1.33it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.86it/s]
#                    all         30         30          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       1/299      1.75G      0.104    0.02262    0.07183         22        416: 100% 8/8 [00:01<00:00,  7.19it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 13.64it/s]
#                    all         30         30          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       2/299      1.75G    0.09801    0.02374    0.07135         15        416: 100% 8/8 [00:01<00:00,  7.90it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 14.86it/s]
#                    all         30         30          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       3/299      1.75G    0.09438    0.02389    0.07138         15        416: 100% 8/8 [00:00<00:00,  8.04it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 15.43it/s]
#                    all         30         30          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       4/299      1.75G    0.09092    0.02793    0.07119         22        416: 100% 8/8 [00:01<00:00,  7.47it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 14.66it/s]
#                    all         30         30          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       5/299      1.75G    0.08898    0.02426    0.07136         19        416: 100% 8/8 [00:01<00:00,  5.81it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  6.67it/s]
#                    all         30         30          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       6/299      1.75G    0.08465    0.02573    0.07107         16        416: 100% 8/8 [00:01<00:00,  7.05it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 14.26it/s]
#                    all         30         30          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       7/299      1.75G    0.08649    0.02723    0.07143         15        416: 100% 8/8 [00:01<00:00,  7.80it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 13.23it/s]
#                    all         30         30          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       8/299      1.75G    0.08105    0.02705    0.07115         18        416: 100% 8/8 [00:01<00:00,  7.92it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 14.38it/s]
#                    all         30         30          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       9/299      1.75G    0.07811    0.02854    0.07101         21        416: 100% 8/8 [00:00<00:00,  8.22it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 15.97it/s]
#                    all         30         30          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      10/299      1.75G    0.07632    0.02619     0.0703         15        416: 100% 8/8 [00:01<00:00,  7.66it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.17s/it]
#                    all         30         30          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      11/299      1.75G    0.07619    0.02733    0.07025         16        416: 100% 8/8 [00:01<00:00,  5.75it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.71it/s]
#                    all         30         30    0.00358      0.733    0.00947    0.00244
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      12/299      1.75G    0.07689    0.02629    0.06974         18        416: 100% 8/8 [00:01<00:00,  7.87it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  5.46it/s]
#                    all         30         30    0.00237        0.6      0.026    0.00803
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      13/299      1.75G    0.07125    0.02731    0.06952         18        416: 100% 8/8 [00:00<00:00,  8.08it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  5.02it/s]
#                    all         30         30    0.00457      0.767     0.0352     0.0107
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      14/299      1.75G     0.0679    0.02753    0.06949         14        416: 100% 8/8 [00:01<00:00,  7.91it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.96it/s]
#                    all         30         30     0.0017        0.5     0.0112    0.00245
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      15/299      1.75G    0.06946    0.02642    0.06918         17        416: 100% 8/8 [00:01<00:00,  7.78it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.79it/s]
#                    all         30         30    0.00327      0.933     0.0366     0.0116
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      16/299      1.75G    0.06664    0.02856    0.06931         17        416: 100% 8/8 [00:01<00:00,  7.77it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.57it/s]
#                    all         30         30    0.00377      0.967     0.0744     0.0191
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      17/299      1.75G    0.06891     0.0255    0.06798         18        416: 100% 8/8 [00:00<00:00,  8.00it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.39it/s]
#                    all         30         30    0.00313      0.933     0.0281    0.00931
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      18/299      1.75G    0.06337    0.02692    0.06838         16        416: 100% 8/8 [00:01<00:00,  5.21it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.79it/s]
#                    all         30         30    0.00299        0.9     0.0547     0.0193
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      19/299      1.75G    0.05908    0.02437    0.06731         12        416: 100% 8/8 [00:01<00:00,  7.73it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.62it/s]
#                    all         30         30    0.00342          1      0.133      0.041
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      20/299      1.75G    0.05923    0.02628    0.06757         17        416: 100% 8/8 [00:01<00:00,  6.01it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.42it/s]
#                    all         30         30    0.00338          1      0.101     0.0373
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      21/299      1.75G    0.05954    0.02467    0.06783         11        416: 100% 8/8 [00:01<00:00,  6.06it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.51it/s]
#                    all         30         30    0.00312      0.933      0.129      0.053
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      22/299      1.75G    0.05798    0.02634    0.06666         19        416: 100% 8/8 [00:00<00:00,  8.08it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.25it/s]
#                    all         30         30     0.0029      0.867     0.0582     0.0154
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      23/299      1.75G    0.05887    0.02319    0.06617         15        416: 100% 8/8 [00:00<00:00,  8.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.49it/s]
#                    all         30         30    0.00335          1      0.122     0.0502
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      24/299      1.75G    0.05657     0.0256    0.06606         18        416: 100% 8/8 [00:01<00:00,  5.14it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.17it/s]
#                    all         30         30    0.00336          1      0.195      0.097
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      25/299      1.75G    0.05696    0.02369    0.06567         14        416: 100% 8/8 [00:01<00:00,  7.85it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.89it/s]
#                    all         30         30     0.0032      0.933      0.154     0.0336
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      26/299      1.75G    0.05416    0.02372    0.06536         15        416: 100% 8/8 [00:00<00:00,  8.17it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.38it/s]
#                    all         30         30      0.606      0.233       0.19      0.047
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      27/299      1.75G    0.05548    0.02357     0.0649         21        416: 100% 8/8 [00:01<00:00,  7.90it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.24it/s]
#                    all         30         30    0.00296      0.867     0.0372     0.0144
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      28/299      1.75G    0.05288    0.02289    0.06422         18        416: 100% 8/8 [00:00<00:00,  8.06it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.58it/s]
#                    all         30         30    0.00219      0.433     0.0365     0.0186
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      29/299      1.75G    0.05166    0.02149    0.06468         16        416: 100% 8/8 [00:01<00:00,  7.67it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.83it/s]
#                    all         30         30    0.00155        0.4     0.0199     0.0117
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      30/299      1.75G    0.05416    0.02064    0.06313         15        416: 100% 8/8 [00:00<00:00,  8.11it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.70it/s]
#                    all         30         30      0.129        0.7      0.372      0.153
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      31/299      1.75G    0.05187    0.02026    0.06308         16        416: 100% 8/8 [00:01<00:00,  5.17it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.60it/s]
#                    all         30         30      0.563      0.161       0.32      0.124
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      32/299      1.75G    0.05202    0.02076    0.06322         17        416: 100% 8/8 [00:00<00:00,  8.09it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.83it/s]
#                    all         30         30      0.531      0.333      0.361      0.145
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      33/299      1.75G    0.04749     0.0201    0.06242         15        416: 100% 8/8 [00:01<00:00,  7.76it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.94it/s]
#                    all         30         30       0.44      0.287      0.311     0.0929
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      34/299      1.75G     0.0513    0.01863    0.06112         13        416: 100% 8/8 [00:01<00:00,  7.89it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.02it/s]
#                    all         30         30      0.754     0.0667      0.189     0.0468
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      35/299      1.75G    0.04722    0.02086    0.06229         24        416: 100% 8/8 [00:00<00:00,  8.16it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.55it/s]
#                    all         30         30      0.273      0.395       0.33     0.0854
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      36/299      1.75G    0.05068    0.01876    0.06047         17        416: 100% 8/8 [00:00<00:00,  8.21it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.71it/s]
#                    all         30         30      0.425      0.493      0.483      0.234
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      37/299      1.75G    0.04829    0.01892    0.05961         14        416: 100% 8/8 [00:01<00:00,  7.59it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.34it/s]
#                    all         30         30      0.417        0.5      0.443      0.181
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      38/299      1.75G    0.04844    0.01904    0.05991         17        416: 100% 8/8 [00:01<00:00,  5.31it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.92it/s]
#                    all         30         30      0.374      0.396      0.323      0.126
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      39/299      1.75G    0.04646    0.01876    0.05986         15        416: 100% 8/8 [00:00<00:00,  8.16it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.98it/s]
#                    all         30         30      0.502      0.267      0.348       0.13
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      40/299      1.75G    0.04536    0.01807    0.06007         19        416: 100% 8/8 [00:00<00:00,  8.10it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  5.10it/s]
#                    all         30         30      0.723      0.267      0.352      0.107
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      41/299      1.75G    0.04677     0.0166    0.05897         13        416: 100% 8/8 [00:00<00:00,  8.02it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  5.03it/s]
#                    all         30         30      0.538      0.375      0.439      0.153
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      42/299      1.75G    0.04374    0.01715     0.0574         15        416: 100% 8/8 [00:00<00:00,  8.02it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  5.01it/s]
#                    all         30         30      0.316      0.467      0.458      0.168
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      43/299      1.75G    0.04296    0.01633    0.05717         15        416: 100% 8/8 [00:00<00:00,  8.05it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.85it/s]
#                    all         30         30      0.619      0.467      0.479      0.185
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      44/299      1.75G    0.04496    0.01614    0.05633         12        416: 100% 8/8 [00:00<00:00,  8.02it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.47it/s]
#                    all         30         30      0.271      0.677      0.486      0.254
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      45/299      1.75G     0.0443    0.01659      0.057         14        416: 100% 8/8 [00:01<00:00,  5.15it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.55it/s]
#                    all         30         30      0.343      0.598      0.513      0.282
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      46/299      1.75G    0.04379    0.01703    0.05591         17        416: 100% 8/8 [00:00<00:00,  8.15it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.78it/s]
#                    all         30         30       0.53      0.586      0.623      0.343
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      47/299      1.75G    0.04492    0.01573    0.05532         14        416: 100% 8/8 [00:01<00:00,  7.91it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.75it/s]
#                    all         30         30      0.555      0.685      0.704      0.362
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      48/299      1.75G    0.04338    0.01652    0.05429         16        416: 100% 8/8 [00:01<00:00,  7.73it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.59it/s]
#                    all         30         30      0.654      0.567      0.673      0.395
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      49/299      1.75G    0.04239     0.0157    0.05394         22        416: 100% 8/8 [00:00<00:00,  8.02it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.57it/s]
#                    all         30         30      0.683        0.3      0.327      0.112
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      50/299      1.75G    0.04155    0.01539    0.05469         11        416: 100% 8/8 [00:00<00:00,  8.02it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.93it/s]
#                    all         30         30      0.619      0.364      0.202      0.089
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      51/299      1.75G    0.04069    0.01613    0.05174         20        416: 100% 8/8 [00:01<00:00,  6.42it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.28it/s]
#                    all         30         30        0.9      0.131      0.206      0.121
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      52/299      1.75G    0.04054    0.01649    0.05274         18        416: 100% 8/8 [00:01<00:00,  6.80it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.81it/s]
#                    all         30         30      0.268      0.757      0.778      0.388
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      53/299      1.75G    0.04085    0.01561    0.05149         15        416: 100% 8/8 [00:01<00:00,  7.57it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.61it/s]
#                    all         30         30      0.242      0.572      0.709      0.318
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      54/299      1.75G    0.03999    0.01584    0.05157         19        416: 100% 8/8 [00:00<00:00,  8.20it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.70it/s]
#                    all         30         30      0.382      0.675      0.769       0.37
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      55/299      1.75G    0.04175    0.01536    0.05299         17        416: 100% 8/8 [00:01<00:00,  7.98it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.92it/s]
#                    all         30         30      0.491      0.793      0.786      0.425
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      56/299      1.75G    0.04091    0.01461    0.05088         16        416: 100% 8/8 [00:01<00:00,  7.84it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  5.09it/s]
#                    all         30         30      0.549      0.767       0.85      0.395
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      57/299      1.75G    0.04092     0.0147    0.05085         15        416: 100% 8/8 [00:00<00:00,  8.03it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  5.07it/s]
#                    all         30         30      0.499      0.733       0.83      0.441
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      58/299      1.75G    0.04181    0.01546    0.04928         14        416: 100% 8/8 [00:01<00:00,  5.21it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.38it/s]
#                    all         30         30      0.631      0.833      0.868      0.441
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      59/299      1.75G    0.04121    0.01514    0.04889         20        416: 100% 8/8 [00:01<00:00,  7.95it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.94it/s]
#                    all         30         30      0.538        0.9      0.817      0.525
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      60/299      1.75G    0.03749    0.01489    0.04808         16        416: 100% 8/8 [00:00<00:00,  8.01it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.57it/s]
#                    all         30         30      0.523      0.807      0.828      0.559
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      61/299      1.75G    0.03931     0.0135    0.04838         16        416: 100% 8/8 [00:00<00:00,  8.00it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.86it/s]
#                    all         30         30      0.544      0.667      0.779      0.493
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      62/299      1.75G    0.03915    0.01386     0.0474         15        416: 100% 8/8 [00:01<00:00,  7.93it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.97it/s]
#                    all         30         30      0.468      0.667      0.774      0.501
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      63/299      1.75G    0.04115    0.01494    0.04886         21        416: 100% 8/8 [00:01<00:00,  7.84it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.94it/s]
#                    all         30         30      0.383        0.8      0.741      0.457
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      64/299      1.75G    0.03993    0.01476    0.04676         19        416: 100% 8/8 [00:00<00:00,  8.16it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.22it/s]
#                    all         30         30      0.531      0.733      0.766      0.473
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      65/299      1.75G    0.03767    0.01368    0.04805         15        416: 100% 8/8 [00:01<00:00,  5.09it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.63it/s]
#                    all         30         30      0.485      0.767      0.808      0.491
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      66/299      1.75G    0.03909    0.01396    0.04551         16        416: 100% 8/8 [00:00<00:00,  8.10it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.70it/s]
#                    all         30         30      0.476      0.867      0.831      0.509
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      67/299      1.75G    0.04119    0.01399    0.04625         16        416: 100% 8/8 [00:01<00:00,  7.93it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.95it/s]
#                    all         30         30      0.536      0.867      0.824      0.445
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      68/299      1.75G    0.03693    0.01382    0.04514         15        416: 100% 8/8 [00:01<00:00,  7.85it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.95it/s]
#                    all         30         30       0.45      0.812      0.818       0.54
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      69/299      1.75G    0.03853    0.01492    0.04545         16        416: 100% 8/8 [00:01<00:00,  7.84it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.92it/s]
#                    all         30         30       0.36      0.733      0.714      0.399
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      70/299      1.75G    0.03822    0.01368    0.04457         17        416: 100% 8/8 [00:01<00:00,  7.83it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.70it/s]
#                    all         30         30      0.498       0.83      0.808      0.466
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      71/299      1.75G    0.03965    0.01513    0.04498         17        416: 100% 8/8 [00:01<00:00,  7.62it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.62it/s]
#                    all         30         30      0.483      0.826      0.806      0.348
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      72/299      1.75G    0.03928    0.01523    0.04234         17        416: 100% 8/8 [00:01<00:00,  5.09it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.24it/s]
#                    all         30         30      0.538      0.885      0.824       0.54
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      73/299      1.75G    0.03731    0.01348     0.0417         14        416: 100% 8/8 [00:01<00:00,  7.92it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.56it/s]
#                    all         30         30      0.597      0.828      0.831      0.594
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      74/299      1.75G    0.03804    0.01324    0.04248         16        416: 100% 8/8 [00:01<00:00,  7.91it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.88it/s]
#                    all         30         30      0.595      0.851      0.865      0.559
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      75/299      1.75G    0.03884    0.01374    0.04369         14        416: 100% 8/8 [00:01<00:00,  7.83it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.88it/s]
#                    all         30         30      0.526      0.916      0.831      0.503
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      76/299      1.75G    0.03856     0.0141    0.04245         15        416: 100% 8/8 [00:01<00:00,  7.67it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  5.00it/s]
#                    all         30         30      0.486      0.927      0.874      0.439
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      77/299      1.75G    0.03576    0.01237    0.03961         14        416: 100% 8/8 [00:01<00:00,  7.84it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  5.40it/s]
#                    all         30         30      0.943        0.2      0.249     0.0986
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      78/299      1.75G    0.03948    0.01338    0.04058         14        416: 100% 8/8 [00:01<00:00,  7.72it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.83it/s]
#                    all         30         30      0.619      0.867      0.894      0.595
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      79/299      1.75G     0.0369     0.0141    0.03981         14        416: 100% 8/8 [00:01<00:00,  5.04it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.80it/s]
#                    all         30         30      0.693      0.933      0.923      0.508
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      80/299      1.75G    0.03662    0.01339    0.03908         15        416: 100% 8/8 [00:01<00:00,  7.81it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.92it/s]
#                    all         30         30      0.663      0.933      0.886       0.45
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      81/299      1.75G    0.03998    0.01292    0.03995         13        416: 100% 8/8 [00:01<00:00,  7.67it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.98it/s]
#                    all         30         30      0.654      0.845      0.936      0.547
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      82/299      1.75G    0.03796    0.01337    0.03962         20        416: 100% 8/8 [00:01<00:00,  7.76it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  5.01it/s]
#                    all         30         30      0.542      0.956      0.905      0.635
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      83/299      1.75G    0.03741    0.01318    0.03632         18        416: 100% 8/8 [00:01<00:00,  7.90it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.91it/s]
#                    all         30         30      0.406      0.667      0.689      0.347
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      84/299      1.75G    0.03567    0.01371    0.03766         16        416: 100% 8/8 [00:00<00:00,  8.15it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.79it/s]
#                    all         30         30      0.524      0.791      0.895      0.523
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      85/299      1.75G    0.03681    0.01308    0.03727         19        416: 100% 8/8 [00:00<00:00,  8.01it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.99it/s]
#                    all         30         30      0.609      0.897      0.914      0.566
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      86/299      1.75G    0.03726     0.0137    0.03517         21        416: 100% 8/8 [00:01<00:00,  5.19it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.31it/s]
#                    all         30         30      0.714      0.849      0.947      0.596
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      87/299      1.75G    0.03561    0.01298    0.03403         14        416: 100% 8/8 [00:01<00:00,  7.79it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  5.04it/s]
#                    all         30         30      0.652      0.948      0.964      0.485
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      88/299      1.75G    0.03496    0.01245    0.03441         13        416: 100% 8/8 [00:01<00:00,  8.00it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.92it/s]
#                    all         30         30      0.674      0.967      0.975      0.672
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      89/299      1.75G    0.03692     0.0143    0.03621         14        416: 100% 8/8 [00:01<00:00,  7.82it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.90it/s]
#                    all         30         30      0.653      0.963      0.955      0.619
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      90/299      1.75G    0.03705    0.01287    0.03433         20        416: 100% 8/8 [00:01<00:00,  7.94it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.67it/s]
#                    all         30         30      0.759      0.967      0.978      0.692
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      91/299      1.75G    0.03599    0.01186    0.03651         15        416: 100% 8/8 [00:00<00:00,  8.12it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.88it/s]
#                    all         30         30      0.634      0.991      0.945      0.628
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      92/299      1.75G    0.03589    0.01363    0.03408         19        416: 100% 8/8 [00:01<00:00,  7.86it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.48it/s]
#                    all         30         30      0.651      0.967      0.945      0.602
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      93/299      1.75G     0.0351    0.01277    0.03248         20        416: 100% 8/8 [00:01<00:00,  5.19it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.64it/s]
#                    all         30         30      0.744      0.867      0.978      0.612
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      94/299      1.75G    0.03744    0.01305    0.03419         14        416: 100% 8/8 [00:00<00:00,  8.10it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  5.14it/s]
#                    all         30         30      0.635        0.9      0.951      0.625
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      95/299      1.75G    0.03665     0.0123    0.03102         20        416: 100% 8/8 [00:00<00:00,  8.06it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.81it/s]
#                    all         30         30      0.713      0.876      0.922      0.599
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      96/299      1.75G    0.03756    0.01257    0.03293         13        416: 100% 8/8 [00:01<00:00,  7.87it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.71it/s]
#                    all         30         30       0.75      0.867      0.975      0.652
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      97/299      1.75G    0.03456     0.0135    0.03057         21        416: 100% 8/8 [00:01<00:00,  7.86it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  5.12it/s]
#                    all         30         30      0.459      0.467      0.481      0.209
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      98/299      1.75G    0.03766    0.01324    0.03185         20        416: 100% 8/8 [00:00<00:00,  8.01it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.86it/s]
#                    all         30         30      0.547      0.638      0.686      0.338
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      99/299      1.75G     0.0348    0.01301    0.02997         23        416: 100% 8/8 [00:01<00:00,  7.93it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.16it/s]
#                    all         30         30      0.711      0.923      0.962      0.672
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     100/299      1.75G    0.03534    0.01213    0.03115         15        416: 100% 8/8 [00:01<00:00,  4.77it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.18it/s]
#                    all         30         30      0.733      0.866      0.984      0.647
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     101/299      1.75G    0.03501    0.01173    0.02992          9        416: 100% 8/8 [00:01<00:00,  7.98it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.77it/s]
#                    all         30         30      0.805      0.977      0.995      0.586
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     102/299      1.75G    0.03569    0.01338    0.02949         19        416: 100% 8/8 [00:01<00:00,  7.86it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  5.12it/s]
#                    all         30         30      0.682      0.974      0.975      0.626
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     103/299      1.75G    0.03824    0.01229    0.02911         16        416: 100% 8/8 [00:00<00:00,  8.09it/s]
# ...
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.89it/s]
#                    all         30         30      0.964          1      0.995      0.785
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     266/299      1.75G    0.02063   0.009948    0.00539         16        416: 100% 8/8 [00:01<00:00,  7.77it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.64it/s]
#                    all         30         30      0.965          1      0.995      0.801
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     267/299      1.75G    0.02042   0.008822   0.006191         15        416: 100% 8/8 [00:01<00:00,  7.76it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.20it/s]
#                    all         30         30      0.967          1      0.995      0.785
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     268/299      1.75G     0.0205   0.009241   0.005974         17        416: 100% 8/8 [00:01<00:00,  4.92it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.55it/s]
#                    all         30         30      0.969          1      0.995      0.765
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     269/299      1.75G    0.02049    0.00943   0.006062         20        416: 100% 8/8 [00:01<00:00,  7.96it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.82it/s]
#                    all         30         30      0.968          1      0.995      0.783
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     270/299      1.75G    0.02214   0.009952    0.00708         21        416: 100% 8/8 [00:01<00:00,  7.78it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.78it/s]
#                    all         30         30      0.966          1      0.995      0.778
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     271/299      1.75G    0.02115   0.008986   0.008101         12        416: 100% 8/8 [00:01<00:00,  7.93it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.96it/s]
#                    all         30         30      0.966          1      0.995      0.783
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     272/299      1.75G    0.02054   0.009168   0.005797         15        416: 100% 8/8 [00:01<00:00,  7.78it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.90it/s]
#                    all         30         30      0.968          1      0.995      0.793
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     273/299      1.75G    0.02117   0.009508   0.005788         17        416: 100% 8/8 [00:01<00:00,  7.76it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.65it/s]
#                    all         30         30      0.968          1      0.995      0.788
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     274/299      1.75G    0.02098   0.009042   0.007056         15        416: 100% 8/8 [00:01<00:00,  7.50it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.44it/s]
#                    all         30         30      0.969          1      0.995      0.796
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     275/299      1.75G    0.02064   0.009388   0.007143         15        416: 100% 8/8 [00:01<00:00,  5.04it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.20it/s]
#                    all         30         30       0.97          1      0.995      0.813
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     276/299      1.75G    0.02069   0.009394   0.006056         15        416: 100% 8/8 [00:01<00:00,  7.61it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.90it/s]
#                    all         30         30       0.97          1      0.995        0.8
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     277/299      1.75G    0.01987   0.008954   0.005371         20        416: 100% 8/8 [00:01<00:00,  7.63it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.75it/s]
#                    all         30         30       0.97          1      0.995      0.776
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     278/299      1.75G    0.02117   0.009953   0.005532         21        416: 100% 8/8 [00:01<00:00,  7.87it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.66it/s]
#                    all         30         30      0.969          1      0.995      0.765
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     279/299      1.75G    0.01954    0.00902   0.005147         19        416: 100% 8/8 [00:01<00:00,  7.66it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.10it/s]
#                    all         30         30      0.969          1      0.995      0.786
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     280/299      1.75G    0.02023   0.008833   0.005466         14        416: 100% 8/8 [00:01<00:00,  5.02it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.37it/s]
#                    all         30         30      0.969          1      0.995      0.768
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     281/299      1.75G    0.01961    0.00803   0.006074         17        416: 100% 8/8 [00:01<00:00,  5.30it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.11it/s]
#                    all         30         30      0.968          1      0.995      0.765
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     282/299      1.75G    0.02011   0.008225   0.005273          8        416: 100% 8/8 [00:00<00:00,  8.09it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.72it/s]
#                    all         30         30      0.969          1      0.995      0.783
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     283/299      1.75G    0.01895   0.009201   0.005692         14        416: 100% 8/8 [00:01<00:00,  7.77it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  5.00it/s]
#                    all         30         30       0.97          1      0.995       0.79
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     284/299      1.75G    0.01941   0.009422   0.005056         15        416: 100% 8/8 [00:01<00:00,  7.85it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.62it/s]
#                    all         30         30      0.969          1      0.995      0.811
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     285/299      1.75G    0.02053   0.009307   0.005818         13        416: 100% 8/8 [00:01<00:00,  7.68it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.86it/s]
#                    all         30         30      0.969          1      0.995      0.801
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     286/299      1.75G    0.01962   0.008856   0.005731         10        416: 100% 8/8 [00:01<00:00,  7.92it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.78it/s]
#                    all         30         30      0.969          1      0.995      0.798
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     287/299      1.75G    0.01819   0.009157   0.004374         14        416: 100% 8/8 [00:01<00:00,  7.75it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.72it/s]
#                    all         30         30       0.97          1      0.995      0.796
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     288/299      1.75G    0.01977   0.008454    0.00555         15        416: 100% 8/8 [00:01<00:00,  5.52it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.78it/s]
#                    all         30         30      0.968          1      0.995      0.815
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     289/299      1.75G    0.01893   0.009593    0.00565         18        416: 100% 8/8 [00:01<00:00,  7.68it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.60it/s]
#                    all         30         30      0.964          1      0.995      0.814
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     290/299      1.75G     0.0188   0.008995     0.0051         19        416: 100% 8/8 [00:01<00:00,  7.87it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.57it/s]
#                    all         30         30      0.964          1      0.995      0.819
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     291/299      1.75G    0.02062   0.009005   0.006473         20        416: 100% 8/8 [00:01<00:00,  7.54it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.78it/s]
#                    all         30         30      0.959          1      0.995      0.808
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     292/299      1.75G    0.02003   0.009009   0.006682         13        416: 100% 8/8 [00:01<00:00,  7.78it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.83it/s]
#                    all         30         30      0.967          1      0.995      0.806
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     293/299      1.75G    0.01857   0.008894   0.005161         16        416: 100% 8/8 [00:01<00:00,  7.82it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.85it/s]
#                    all         30         30      0.969          1      0.995      0.815
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     294/299      1.75G    0.01828   0.008567   0.004987         15        416: 100% 8/8 [00:01<00:00,  7.91it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.61it/s]
#                    all         30         30      0.971          1      0.995       0.83
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     295/299      1.75G    0.01866   0.008417   0.004749         18        416: 100% 8/8 [00:01<00:00,  5.26it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.83it/s]
#                    all         30         30      0.971          1      0.995       0.82
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     296/299      1.75G      0.019   0.009085   0.006457         15        416: 100% 8/8 [00:01<00:00,  7.61it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.81it/s]
#                    all         30         30      0.972          1      0.995       0.82
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     297/299      1.75G    0.01921   0.009215   0.005185         22        416: 100% 8/8 [00:01<00:00,  7.85it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.64it/s]
#                    all         30         30      0.973          1      0.995      0.818
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     298/299      1.75G    0.01861   0.008899   0.005177         13        416: 100% 8/8 [00:01<00:00,  7.85it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.89it/s]
#                    all         30         30      0.973          1      0.995       0.81
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     299/299      1.75G    0.01767   0.008698   0.004632         16        416: 100% 8/8 [00:01<00:00,  7.54it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.52it/s]
#                    all         30         30      0.972          1      0.995       0.81
#
# 300 epochs completed in 0.152 hours.
# Optimizer stripped from runs/train/yolov5s_results/weights/last.pt, 14.8MB
# Optimizer stripped from runs/train/yolov5s_results/weights/best.pt, 14.8MB
#
# Validating runs/train/yolov5s_results/weights/best.pt...
# Fusing layers...
# custom_YOLOv5s summary: 182 layers, 7284276 parameters, 0 gradients
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.19it/s]
#                    all         30         30      0.971          1      0.995       0.83
#                    Bad         30          2      0.967          1      0.995      0.821
#                   Good         30          2       0.98          1      0.995      0.622
#                Goodbye         30          2      0.969          1      0.995      0.946
#                  Hello         30          2      0.967          1      0.995      0.846
#                   Help         30          2      0.968          1      0.995      0.846
#                  House         30          2      0.966          1      0.995      0.895
#                   Hurt         30          2      0.981          1      0.995      0.821
#             I love you         30          2      0.975          1      0.995      0.895
#                   Nice         30          2      0.971          1      0.995      0.797
#                     No         30          2      0.972          1      0.995      0.895
#                 Please         30          2      0.964          1      0.995      0.821
#                  Sorry         30          2      0.973          1      0.995      0.747
#              Thank you         30          2      0.962          1      0.995      0.895
#                 Toilet         30          2      0.974          1      0.995      0.846
#                    Yes         30          2       0.98          1      0.995      0.747
# Results saved to runs/train/yolov5s_results
# CPU times: user 6.08 s, sys: 697 ms, total: 6.78 s
# Wall time: 9min 34s

# %%
# %load_ext tensorboard
# %tensorboard --logdir runs
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6006 (pid 20023), started 0:00:21 ago. (Use '!kill 20023' to kill it.)

# %%
# !nvidia-smi
# Out:
# Sun Mar 17 20:20:01 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8               9W /  70W |      3MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
from utils.plots import plot_results  # plot results.txt as results.png
Image(filename='/content/yolov5/runs/train/yolov5s_results/results.png', width=1000)  # view results.png

# %%
print("GROUND TRUTH TRAINING DATA:")
Image(filename='/content/yolov5/runs/train/yolov5s_results/val_batch0_labels.jpg', width=900)
# Out:
# GROUND TRUTH TRAINING DATA:

# %%
print("GROUND TRUTH AUGMENTED TRAINING DATA:")
Image(filename='/content/yolov5/runs/train/yolov5s_results/train_batch0.jpg', width=900)
# Out:
# GROUND TRUTH AUGMENTED TRAINING DATA:

# %%
# trained weights are saved by default in our weights folder
# %ls runs/
# Out:
# train/

# %%
# %ls runs/train/yolov5s_results/weights
# Out:
# best.pt  last.pt

# %%
# use the best weights
# %cd /content/yolov5/
# !python detect.py --weights /content/yolov5/runs/train/yolov5s_results/weights/best.pt --img 416 --conf 0.1 --source ../test/images
# Out:
# /content/yolov5
# detect: weights=['/content/yolov5/runs/train/yolov5s_results/weights/best.pt'], source=../test/images, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-294-gdb125a20 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# custom_YOLOv5s summary: 182 layers, 7284276 parameters, 0 gradients
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/30 /content/test/images/Bad_87658c00-e29a-11ee-a9cf-3e960304d18e.jpg: 256x416 1 Bad, 73.8ms
# image 2/30 /content/test/images/Bad_9116bd28-e29a-11ee-a9cf-3e960304d18e.jpg: 256x416 1 Bad, 12.8ms
# image 3/30 /content/test/images/Good_80981528-e29a-11ee-a9cf-3e960304d18e.jpg: 256x416 1 Good, 12.9ms
# image 4/30 /content/test/images/Good_8306121a-e29a-11ee-a9cf-3e960304d18e.jpg: 256x416 1 Good, 6.5ms
# image 5/30 /content/test/images/Goodbye_fde8cfaa-e299-11ee-a9cf-3e960304d18e.jpg: 256x416 1 Goodbye, 9.7ms
# image 6/30 /content/test/images/Goodbye_ff1ed61c-e299-11ee-a9cf-3e960304d18e.jpg: 256x416 1 Goodbye, 6.5ms
# image 7/30 /content/test/images/Hello_d149131a-e299-11ee-a9cf-3e960304d18e.jpg: 256x416 1 Hello, 6.3ms
# image 8/30 /content/test/images/Hello_daf9ffa0-e299-11ee-a9cf-3e960304d18e.jpg: 256x416 1 Hello, 6.3ms
# image 9/30 /content/test/images/Help_30946e28-e29a-11ee-a9cf-3e960304d18e.jpg: 256x416 1 Help, 6.3ms
# image 10/30 /content/test/images/Help_330090f6-e29a-11ee-a9cf-3e960304d18e.jpg: 256x416 1 Help, 6.6ms
# image 11/30 /content/test/images/House_4111e500-e29a-11ee-a9cf-3e960304d18e.jpg: 256x416 1 House, 6.3ms
# image 12/30 /content/test/images/House_42480666-e29a-11ee-a9cf-3e960304d18e.jpg: 256x416 1 House, 9.7ms
# image 13/30 /content/test/images/Hurt_afa22a98-e29a-11ee-a9cf-3e960304d18e.jpg: 256x416 1 Hurt, 6.7ms
# image 14/30 /content/test/images/Hurt_b0d8d5ce-e29a-11ee-a9cf-3e960304d18e.jpg: 256x416 1 Hurt, 6.3ms
# image 15/30 /content/test/images/Iloveyou_e0916c96-e299-11ee-a9cf-3e960304d18e.jpg: 256x416 1 I love you, 6.3ms
# image 16/30 /content/test/images/Iloveyou_ea429512-e299-11ee-a9cf-3e960304d18e.jpg: 256x416 1 I love you, 9.4ms
# image 17/30 /content/test/images/Nice_a05c036a-e29a-11ee-a9cf-3e960304d18e.jpg: 256x416 1 Nice, 6.3ms
# image 18/30 /content/test/images/Nice_a19232d6-e29a-11ee-a9cf-3e960304d18e.jpg: 256x416 1 Nice, 6.6ms
# image 19/30 /content/test/images/No_7151f6ce-e29a-11ee-a9cf-3e960304d18e.jpg: 256x416 1 No, 6.3ms
# image 20/30 /content/test/images/No_728821c6-e29a-11ee-a9cf-3e960304d18e.jpg: 256x416 1 No, 9.4ms
# image 21/30 /content/test/images/Please_201885fc-e29a-11ee-a9cf-3e960304d18e.jpg: 256x416 1 Please, 6.3ms
# image 22/30 /content/test/images/Please_2284913c-e29a-11ee-a9cf-3e960304d18e.jpg: 256x416 1 Please, 6.3ms
# image 23/30 /content/test/images/Sorry_120800a0-e29a-11ee-a9cf-3e960304d18e.jpg: 256x416 1 Sorry, 8.1ms
# image 24/30 /content/test/images/Sorry_14744ba0-e29a-11ee-a9cf-3e960304d18e.jpg: 256x416 1 Sorry, 6.4ms
# image 25/30 /content/test/images/Thankyou_f8532cf2-e299-11ee-a9cf-3e960304d18e.jpg: 256x416 1 Thank you, 6.7ms
# image 26/30 /content/test/images/Thankyou_f98986a2-e299-11ee-a9cf-3e960304d18e.jpg: 256x416 1 Thank you, 6.4ms
# image 27/30 /content/test/images/Toilet_5058add2-e29a-11ee-a9cf-3e960304d18e.jpg: 256x416 1 Toilet, 7.1ms
# image 28/30 /content/test/images/Toilet_553148e6-e29a-11ee-a9cf-3e960304d18e.jpg: 256x416 1 Toilet, 6.4ms
# image 29/30 /content/test/images/Yes_5990517a-e29a-11ee-a9cf-3e960304d18e.jpg: 256x416 1 Yes, 6.4ms
# image 30/30 /content/test/images/Yes_6341396e-e29a-11ee-a9cf-3e960304d18e.jpg: 256x416 1 Yes, 6.8ms
# Speed: 0.2ms pre-process, 9.6ms inference, 31.4ms NMS per image at shape (1, 3, 416, 416)
# Results saved to runs/detect/exp

# %%
import glob
from IPython.display import Image, display

for imageName in glob.glob('/content/yolov5/runs/detect/exp*.jpg'): #assuming JPG
    display(Image(filename=imageName))
    print("\n")

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cp /content/yolov5/runs/train/yolov5s_results/weights/best.pt /content/gdrive/MyDrive/Sign Language Detection Model (Major Project)
# Out:
# /bin/bash: -c: line 1: syntax error near unexpected token `('
# /bin/bash: -c: line 1: `cp /content/yolov5/runs/train/yolov5s_results/weights/best.pt /content/gdrive/MyDrive/Sign Language Detection Model (Major Project)'
